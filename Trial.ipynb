# %% [markdown]
# <a href="https://colab.research.google.com/github/LordOfHeat01/Adrde-Object-Classification-/blob/main/Trial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Task
# Clone the GitHub repository 'https://github.com/LordOfHeat01/Adrde-Object-Classification-.git' into the Colab environment.

# %% [markdown]
# ## Clone GitHub Repository
#
# ### Subtask:
# Clone the provided GitHub repository 'https://github.com/LordOfHeat01/Adrde-Object-Classification-.git' into the Colab environment. This will make all the files from your repository accessible in Colab.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipython-input-1408506528.py in <cell line: 0>()
#       1 from google.colab import drive
# ----> 2 drive.mount('/content/drive')
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
#     136         request={'authType': 'dfs_ephemeral'},
#
# ...

# %% [markdown]
# **Reasoning**:
# To clone the GitHub repository, I will use the `!git clone` command in a code cell, providing the specified repository URL.

# %%
print('Cloning the GitHub repository...')
# !git clone https://github.com/LordOfHeat01/Adrde-Object-Classification-.git
print('Repository cloned successfully.')

# %% [markdown]
# ## Access Cloned Repository and Begin Work
#
# ### Subtask:
# After cloning, your repository will be accessible in the Colab file browser. You can then navigate into the cloned directory and start working on your project, for example, by creating new files or modifying existing ones. I will also provide guidance on how to save changes and push them back to GitHub if you wish.

# %% [markdown]
# **Reasoning**:
# To verify that the repository has been cloned and is accessible, I will list the contents of the current directory, which should include the 'Adrde-Object-Classification-' folder.

# %%
print("Listing contents of the current directory to verify cloned repository:")
# !ls -F
# Out:
# Listing contents of the current directory to verify cloned repository:
# Adrde-Object-Classification-/  sample_data/

# %%
print('Happy Birthday to Tapendra Verma')
# Out:
# Happy Birthday to Tapendra Verma

# %% [markdown]
# The repository `Adrde-Object-Classification-/` has been successfully cloned and is visible. You can click the folder icon on the left-hand pane in Colab to see the file structure.
#
# As the previous output indicated, the repository was empty upon cloning. To begin working, you can navigate into this directory using the `cd` command in a new code cell (e.g., `cd Adrde-Object-Classification-`). Once inside, you can create new files or upload existing ones.
#
# If you plan to save changes and push them back to GitHub, you will need to configure your Git credentials. This typically involves setting your user name and email. For example:
#
# ```python
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"
# ```
#
# After configuring, you can use standard Git commands like `!git add .`, `!git commit -m "Your commit message"`, and `!git push origin main` (or `master`, depending on your branch name) to manage your changes.

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the repository is connected and provide instructions for the next steps.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# The repository 'https://github.com/LordOfHeat01/Adrde-Object-Classification-.git' has been successfully connected (cloned) to the Colab environment.
#
# ### Data Analysis Key Findings
# *   The GitHub repository `https://github.com/LordOfHeat01/Adrde-Object-Classification-.git` was successfully cloned into the Colab environment using the `!git clone` command.
# *   A warning message, "warning: You appear to have cloned an empty repository.", was received, indicating that the repository contained no files at the time of cloning.
# *   Despite the warning, the cloning process was successful, and the `Adrde-Object-Classification-/` directory was confirmed to be present in the Colab file system.
#
# ### Insights or Next Steps
# *   To start working on the project, navigate into the cloned directory `Adrde-Object-Classification-` using the `cd` command and then create or upload necessary files.
# *   To push any changes back to the GitHub repository, configure your Git credentials (user email and name) within Colab and then use standard Git commands such as `git add`, `git commit`, and `git push`.

# %%
print('Navigating into the cloned repository directory...')
# %cd Adrde-Object-Classification-/
print('Current directory after navigation:')
# !pwd

# %% [markdown]
# Next, you need to configure your Git credentials. **Please replace `"you@example.com"` with your GitHub registered email and `"Your Name"` with your GitHub username before running the following cells.**

# %%
# Configure your Git user email
# !git config --global user.email "tapendraverma2012@gmail.com"

# %%
# Configure your Git user name
# !git config --global user.name "LordOfHeat01"

# %% [markdown]
# Once these steps are complete, you can create or modify files within the `Adrde-Object-Classification-` directory. After making changes, you will use the following commands to push them to GitHub:
#
# 1.  `!git add .` (to stage all changes)
# 2.  `!git commit -m "Your commit message"` (to commit your changes)
# 3.  `!git push origin main` (to push to your `main` branch, or `master` if that's your default branch)

# %%
print("ADRDE Object Classification Project")
print("Colab is successfully connected with GitHub")

a = 10
b = 20
print("Sum of a and b is:", a + b)
# Out:
# ADRDE Object Classification Project
# Colab is successfully connected with GitHub
# Sum of a and b is: 30

# %%
# !git add .
